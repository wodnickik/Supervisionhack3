# %%
# Copyright (c) Meta Platforms, Inc. and affiliates.

# %% [markdown]
# # Automatically generating object masks with SAM

# %% [markdown]
# Since SAM can efficiently process prompts, masks for the entire image can be generated by sampling a large number of prompts over an image. This method was used to generate the dataset SA-1B.
#
# The class `SamAutomaticMaskGenerator` implements this capability. It works by sampling single-point input prompts in a grid over the image, from each of which SAM can predict multiple masks. Then, masks are filtered for quality and deduplicated using non-maximal suppression. Additional options allow for further improvement of mask quality and quantity, such as running prediction on multiple crops of the image or postprocessing masks to remove small disconnected regions and holes.

# %%
from IPython.display import display, HTML
display(HTML(
"""
<a target="_blank" href="https://colab.research.google.com/github/facebookresearch/segment-anything/blob/main/notebooks/automatic_mask_generator_example.ipynb">
  <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
</a>
"""
))
# Out:
# <a target="_blank" href="https://colab.research.google.com/github/facebookresearch/segment-anything/blob/main/notebooks/automatic_mask_generator_example.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %% [markdown]
# ## Environment Set-up

# %% [markdown]
# If running locally using jupyter, first install `segment_anything` in your environment using the [installation instructions](https://github.com/facebookresearch/segment-anything#installation) in the repository. If running from Google Colab, set `using_colab=True` below and run the cell. In Colab, be sure to select 'GPU' under 'Edit'->'Notebook Settings'->'Hardware accelerator'.

# %%
using_colab = False

# %%
if using_colab:
    import torch
    import torchvision
    print("PyTorch version:", torch.__version__)
    print("Torchvision version:", torchvision.__version__)
    print("CUDA is available:", torch.cuda.is_available())
    import sys
    # !{sys.executable} -m pip install opencv-python matplotlib
    # !{sys.executable} -m pip install 'git+https://github.com/facebookresearch/segment-anything.git'
    
    # !mkdir images
    # !wget -P images https://raw.githubusercontent.com/facebookresearch/segment-anything/main/notebooks/images/dog.jpg
        
    # !wget https://dl.fbaipublicfiles.com/segment_anything/sam_vit_h_4b8939.pth

# %% [markdown]
# ## Set-up

# %%
import numpy as np
import torch
import matplotlib.pyplot as plt
import cv2

# %%
def show_anns(anns):
    if len(anns) == 0:
        return
    sorted_anns = sorted(anns, key=(lambda x: x['area']), reverse=True)
    ax = plt.gca()
    ax.set_autoscale_on(False)

    img = np.ones((sorted_anns[0]['segmentation'].shape[0], sorted_anns[0]['segmentation'].shape[1], 4))
    img[:,:,3] = 0
    for ann in sorted_anns:
        m = ann['segmentation']
        color_mask = np.concatenate([np.random.random(3), [0.35]])
        img[m] = color_mask
    ax.imshow(img)

# %% [markdown]
# ## Example image

# %%
image = cv2.imread('test1/test1-2.jpg')
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# %%
plt.figure(figsize=(20,20))
plt.imshow(image)
plt.axis('off')
plt.show()

# %% [markdown]
# ## Automatic mask generation

# %% [markdown]
# To run automatic mask generation, provide a SAM model to the `SamAutomaticMaskGenerator` class. Set the path below to the SAM checkpoint. Running on CUDA and with the default model is recommended.

# %%
# import sys
# sys.path.append("..")
from segment_anything import sam_model_registry, SamAutomaticMaskGenerator, SamPredictor

sam_checkpoint = "sam_vit_h_4b8939.pth"
model_type = "vit_h"

device = "cuda"

sam = sam_model_registry[model_type](checkpoint=sam_checkpoint)
sam.to(device=device)

mask_generator = SamAutomaticMaskGenerator(sam)

# %% [markdown]
# To generate masks, just run `generate` on an image.

# %%
masks = mask_generator.generate(image)

# %%
len(masks)
# Out:
# 45

# %% [markdown]
# Mask generation returns a list over masks, where each mask is a dictionary containing various data about the mask. These keys are:
# * `segmentation` : the mask
# * `area` : the area of the mask in pixels
# * `bbox` : the boundary box of the mask in XYWH format
# * `predicted_iou` : the model's own prediction for the quality of the mask
# * `point_coords` : the sampled input point that generated this mask
# * `stability_score` : an additional measure of mask quality
# * `crop_box` : the crop of the image used to generate this mask in XYWH format

# %%
print(len(masks))
print(masks[0].keys())
# Out:
# 45
# dict_keys(['segmentation', 'area', 'bbox', 'predicted_iou', 'point_coords', 'stability_score', 'crop_box'])

# %%
masks
# Out:
# [{'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 524063,
#   'bbox': [118.0, 1529.0, 1378.0, 384.0],
#   'predicted_iou': 1.0177443027496338,
#   'point_coords': [[749.46875, 1571.515625]],
#   'stability_score': 0.9791718125343323,
#   'crop_box': [0, 0, 1654, 2339]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 305603,
#   'bbox': [119.0, 571.0, 1376.0, 226.0],
#   'predicted_iou': 1.0154139995574951,
#   'point_coords': [[852.84375, 694.390625]],
#   'stability_score': 0.977980375289917,
#   'crop_box': [0, 0, 1654, 2339]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 583287,
#   'bbox': [116.0, 134.0, 1381.0, 434.0],
#   'predicted_iou': 1.0144144296646118,
#   'point_coords': [[1214.65625, 548.203125]],
#   'stability_score': 0.9572101831436157,
#   'crop_box': [0, 0, 1654, 2339]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 270656,
#   'bbox': [119.0, 1298.0, 1375.0, 202.0],
#   'predicted_iou': 0.9916530847549438,
#   'point_coords': [[852.84375, 1352.234375]],
#   'stability_score': 0.9698235988616943,
#   'crop_box': [0, 0, 1654, 2339]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 566805,
#   'bbox': [117.0, 136.0, 1378.0, 655.0],
#   'predicted_iou': 0.9875876307487488,
#   'point_coords': [[1473.09375, 255.828125]],
#   'stability_score': 0.9656050801277161,
#   'crop_box': [0, 0, 1654, 2339]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 524282,
#   'bbox': [118.0, 1304.0, 1379.0, 609.0],
#   'predicted_iou': 0.9797582030296326,
#   'point_coords': [[594.40625, 1790.796875]],
#   'stability_score': 0.978005051612854,
#   'crop_box': [0, 0, 1654, 2339]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 253295,
#   'bbox': [118.0, 832.0, 1377.0, 200.0],
#   'predicted_iou': 0.9656068086624146,
#   'point_coords': [[1162.96875, 913.671875]],
#   'stability_score': 0.953160285949707,
#   'crop_box': [0, 0, 1654, 2339]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 877,
#   'bbox': [1071.0, 2076.0, 71.0, 14.0],
#   'predicted_iou': 0.9522197246551514,
#   'point_coords': [[1111.28125, 2083.171875]],
#   'stability_score': 0.9762979745864868,
#   'crop_box': [0, 0, 1654, 2339]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 813,
#   'bbox': [1271.0, 2077.0, 64.0, 13.0],
#   'predicted_iou': 0.9517732262611389,
#   'point_coords': [[1318.03125, 2083.171875]],
#   'stability_score': 0.9841269850730896,
#   'crop_box': [0, 0, 1654, 2339]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 1558,
#   'bbox': [319.0, 1773.0, 87.0, 20.0],
#   'predicted_iou': 0.9466391205787659,
#   'point_coords': [[387.65625, 1790.796875]],
#   'stability_score': 0.9667085409164429,
#   'crop_box': [0, 0, 1654, 2339]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 907,
#   'bbox': [1195.0, 2076.0, 70.0, 15.0],
#   'predicted_iou': 0.9460926651954651,
#   'point_coords': [[1214.65625, 2083.171875]],
#   'stability_score': 0.9846659302711487,
#   'crop_box': [0, 0, 1654, 2339]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 1261,
#   'bbox': [630.0, 2077.0, 90.0, 15.0],
#   'predicted_iou': 0.9449009299278259,
#   'point_coords': [[697.78125, 2083.171875]],
#   'stability_score': 0.9858490824699402,
#   'crop_box': [0, 0, 1654, 2339]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 703,
#   'bbox': [1011.0, 2076.0, 54.0, 13.0],
#   'predicted_iou': 0.9445340037345886,
#   'point_coords': [[1059.59375, 2083.171875]],
#   'stability_score': 0.9914893507957458,
#   'crop_box': [0, 0, 1654, 2339]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 891,
#   'bbox': [995.0, 402.0, 42.0, 22.0],
#   'predicted_iou': 0.942319393157959,
#   'point_coords': [[1007.90625, 402.015625]],
#   'stability_score': 0.9800443649291992,
#   'crop_box': [0, 0, 1654, 2339]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 841,
#   'bbox': [560.0, 2076.0, 64.0, 14.0],
#   'predicted_iou': 0.9414941668510437,
#   'point_coords': [[594.40625, 2083.171875]],
#   'stability_score': 0.9823113083839417,
#   'crop_box': [0, 0, 1654, 2339]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 836,
#   'bbox': [1342.0, 2075.0, 64.0, 15.0],
#   'predicted_iou': 0.9377402067184448,
#   'point_coords': [[1369.71875, 2083.171875]],
#   'stability_score': 0.9881235361099243,
#   'crop_box': [0, 0, 1654, 2339]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 1288,
#   'bbox': [905.0, 2075.0, 99.0, 15.0],
#   'predicted_iou': 0.9369083642959595,
#   'point_coords': [[956.21875, 2083.171875]],
#   'stability_score': 0.9800153970718384,
#   'crop_box': [0, 0, 1654, 2339]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 658,
#   'bbox': [737.0, 2076.0, 47.0, 17.0],
#   'predicted_iou': 0.936127781867981,
#   'point_coords': [[749.46875, 2083.171875]],
#   'stability_score': 0.9894259572029114,
#   'crop_box': [0, 0, 1654, 2339]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 3031,
#   'bbox': [126.0, 1120.0, 165.0, 23.0],
#   'predicted_iou': 0.9329296350479126,
#   'point_coords': [[232.59375, 1132.953125]],
#   'stability_score': 0.9526417255401611,
#   'crop_box': [0, 0, 1654, 2339]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 1155,
#   'bbox': [814.0, 2077.0, 86.0, 16.0],
#   'predicted_iou': 0.9315361380577087,
#   'point_coords': [[852.84375, 2083.171875]],
#   'stability_score': 0.9845361113548279,
#   'crop_box': [0, 0, 1654, 2339]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 789,
#   'bbox': [1449.0, 403.0, 40.0, 20.0],
#   'predicted_iou': 0.9255321621894836,
#   'point_coords': [[1473.09375, 402.015625]],
#   'stability_score': 0.9737171530723572,
#   'crop_box': [0, 0, 1654, 2339]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 1053,
#   'bbox': [306.0, 1572.0, 60.0, 21.0],
#   'predicted_iou': 0.9248451590538025,
#   'point_coords': [[335.96875, 1571.515625]],
#   'stability_score': 0.9746953845024109,
#   'crop_box': [0, 0, 1654, 2339]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 1100,
#   'bbox': [613.0, 1055.0, 71.0, 17.0],
#   'predicted_iou': 0.9246408939361572,
#   'point_coords': [[646.09375, 1059.859375]],
#   'stability_score': 0.9766606688499451,
#   'crop_box': [0, 0, 1654, 2339]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 1447,
#   'bbox': [1412.0, 2077.0, 108.0, 15.0],
#   'predicted_iou': 0.9212638139724731,
#   'point_coords': [[1421.40625, 2083.171875]],
#   'stability_score': 0.9814814925193787,
#   'crop_box': [0, 0, 1654, 2339]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 2073,
#   'bbox': [1261.0, 1121.0, 118.0, 21.0],
#   'predicted_iou': 0.920735776424408,
#   'point_coords': [[1369.71875, 1132.953125]],
#   'stability_score': 0.955986738204956,
#   'crop_box': [0, 0, 1654, 2339]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 760,
#   'bbox': [1449.0, 751.0, 39.0, 19.0],
#   'predicted_iou': 0.920367419719696,
#   'point_coords': [[1473.09375, 767.484375]],
#   'stability_score': 0.9817232489585876,
#   'crop_box': [0, 0, 1654, 2339]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 1918,
#   'bbox': [198.0, 1773.0, 113.0, 19.0],
#   'predicted_iou': 0.9180691242218018,
#   'point_coords': [[284.28125, 1790.796875]],
#   'stability_score': 0.9757606983184814,
#   'crop_box': [0, 0, 1654, 2339]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 1031,
#   'bbox': [128.0, 1774.0, 63.0, 20.0],
#   'predicted_iou': 0.916121780872345,
#   'point_coords': [[180.90625, 1790.796875]],
#   'stability_score': 0.9703349471092224,
#   'crop_box': [0, 0, 1654, 2339]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 1021,
#   'bbox': [781.0, 235.0, 58.0, 21.0],
#   'predicted_iou': 0.9110831618309021,
#   'point_coords': [[801.15625, 255.828125]],
#   'stability_score': 0.9815713167190552,
#   'crop_box': [0, 0, 1654, 2339]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 236,
#   'bbox': [1526.0, 2078.0, 21.0, 11.0],
#   'predicted_iou': 0.9100298285484314,
#   'point_coords': [[1524.78125, 2083.171875]],
#   'stability_score': 0.9789915680885315,
#   'crop_box': [0, 0, 1654, 2339]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 1403,
#   'bbox': [760.0, 1705.0, 77.0, 19.0],
#   'predicted_iou': 0.9097331166267395,
#   'point_coords': [[801.15625, 1717.703125]],
#   'stability_score': 0.9657342433929443,
#   'crop_box': [0, 0, 1654, 2339]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 231,
#   'bbox': [790.0, 2076.0, 19.0, 13.0],
#   'predicted_iou': 0.9096830487251282,
#   'point_coords': [[801.15625, 2083.171875]],
#   'stability_score': 0.9703390002250671,
#   'crop_box': [0, 0, 1654, 2339]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 863,
#   'bbox': [374.0, 1571.0, 47.0, 18.0],
#   'predicted_iou': 0.9094709753990173,
#   'point_coords': [[387.65625, 1571.515625]],
#   'stability_score': 0.985023021697998,
#   'crop_box': [0, 0, 1654, 2339]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 1282,
#   'bbox': [226.0, 2075.0, 87.0, 18.0],
#   'predicted_iou': 0.9093323945999146,
#   'point_coords': [[284.28125, 2083.171875]],
#   'stability_score': 0.9721792936325073,
#   'crop_box': [0, 0, 1654, 2339]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 1729,
#   'bbox': [846.0, 235.0, 104.0, 22.0],
#   'predicted_iou': 0.908508837223053,
#   'point_coords': [[904.53125, 255.828125]],
#   'stability_score': 0.9636157155036926,
#   'crop_box': [0, 0, 1654, 2339]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 1210,
#   'bbox': [444.0, 2077.0, 110.0, 13.0],
#   'predicted_iou': 0.9071852564811707,
#   'point_coords': [[542.71875, 2083.171875]],
#   'stability_score': 0.9619433283805847,
#   'crop_box': [0, 0, 1654, 2339]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 1551,
#   'bbox': [904.0, 1054.0, 94.0, 22.0],
#   'predicted_iou': 0.9068059325218201,
#   'point_coords': [[956.21875, 1059.859375]],
#   'stability_score': 0.9683343768119812,
#   'crop_box': [0, 0, 1654, 2339]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 2676,
#   'bbox': [907.0, 1055.0, 252.0, 21.0],
#   'predicted_iou': 0.9065328240394592,
#   'point_coords': [[1059.59375, 1059.859375]],
#   'stability_score': 0.9594890475273132,
#   'crop_box': [0, 0, 1654, 2339]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 1957,
#   'bbox': [1168.0, 1054.0, 115.0, 20.0],
#   'predicted_iou': 0.9059267044067383,
#   'point_coords': [[1266.34375, 1059.859375]],
#   'stability_score': 0.973737359046936,
#   'crop_box': [0, 0, 1654, 2339]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 217,
#   'bbox': [1148.0, 2078.0, 17.0, 14.0],
#   'predicted_iou': 0.9024049639701843,
#   'point_coords': [[1162.96875, 2083.171875]],
#   'stability_score': 0.9817351698875427,
#   'crop_box': [0, 0, 1654, 2339]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 1821,
#   'bbox': [127.0, 1571.0, 111.0, 19.0],
#   'predicted_iou': 0.900912880897522,
#   'point_coords': [[129.21875, 1571.515625]],
#   'stability_score': 0.9660010933876038,
#   'crop_box': [0, 0, 1654, 2339]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 1779,
#   'bbox': [462.0, 1054.0, 120.0, 21.0],
#   'predicted_iou': 0.8995681405067444,
#   'point_coords': [[542.71875, 1059.859375]],
#   'stability_score': 0.9554945230484009,
#   'crop_box': [0, 0, 1654, 2339]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 3670,
#   'bbox': [616.0, 1053.0, 379.0, 23.0],
#   'predicted_iou': 0.8967056274414062,
#   'point_coords': [[852.84375, 1059.859375]],
#   'stability_score': 0.9661926627159119,
#   'crop_box': [0, 0, 1654, 2339]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 1200,
#   'bbox': [843.0, 1706.0, 66.0, 20.0],
#   'predicted_iou': 0.8947964906692505,
#   'point_coords': [[852.84375, 1717.703125]],
#   'stability_score': 0.9519544243812561,
#   'crop_box': [0, 0, 1654, 2339]},
#  {'segmentation': array([[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]),
#   'area': 736,
#   'bbox': [1449.0, 452.0, 40.0, 20.0],
#   'predicted_iou': 0.8845541477203369,
#   'point_coords': [[1473.09375, 475.109375]],
#   'stability_score': 0.9546666741371155,
#   'crop_box': [0, 0, 1654, 2339]}]

# %%
masks = sorted(masks, key=(lambda x: x['predicted_iou']), reverse=True)

# %% [markdown]
# Show all the masks overlayed on the image.

# %%
plt.figure(figsize=(20,20))
plt.imshow(image)
show_anns(masks[:3])
plt.axis('off')
plt.show()

# %% [markdown]
# ## Automatic mask generation options

# %% [markdown]
# There are several tunable parameters in automatic mask generation that control how densely points are sampled and what the thresholds are for removing low quality or duplicate masks. Additionally, generation can be automatically run on crops of the image to get improved performance on smaller objects, and post-processing can remove stray pixels and holes. Here is an example configuration that samples more masks:

# %%
mask_generator_2 = SamAutomaticMaskGenerator(
    model=sam,
    points_per_side=32,
    pred_iou_thresh=0.86,
    stability_score_thresh=0.92,
    crop_n_layers=1,
    crop_n_points_downscale_factor=2,
    min_mask_region_area=100,  # Requires open-cv to run post-processing
)

# %%
masks2 = mask_generator_2.generate(image)

# %%
len(masks2)
# Out:
# 123

# %%
masks2 = sorted(masks2, key=(lambda x: x['predicted_iou']), reverse=True)

# %%
masks2[0]
# Out:
# {'segmentation': array([[False, False, False, ..., False, False, False],
#         [False, False, False, ..., False, False, False],
#         [False, False, False, ..., False, False, False],
#         ...,
#         [False, False, False, ..., False, False, False],
#         [False, False, False, ..., False, False, False],
#         [False, False, False, ..., False, False, False]]),
#  'area': 524063,
#  'bbox': [118.0, 1529.0, 1378.0, 384.0],
#  'predicted_iou': 1.0177443027496338,
#  'point_coords': [[749.46875, 1571.515625]],
#  'stability_score': 0.9791718125343323,
#  'crop_box': [0, 0, 1654, 2339]}

# %%
image.shape
# Out:
# (2339, 1654, 3)

# %%
plt.figure(figsize=(20,20))
plt.imshow(image)
show_anns(masks2[:20])
# plot rectangle around the mask
plt.axis('off')
plt.show()

# %%
# crop pdf

# %%
tmp.pages[0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/majkel/segment-anything/notebooks/automatic_mask_generator_example copy.ipynb Cell 37 line 1
# ----> <a href='vscode-notebook-cell://wsl%2Bubuntu/home/majkel/segment-anything/notebooks/automatic_mask_generator_example%20copy.ipynb#X51sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> tmp.pages[0]
#
# NameError: name 'tmp' is not defined
